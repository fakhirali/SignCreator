# %%
import cv2
import matplotlib.pyplot as plt

# %%
a = cv2.imread("Sign.jpg")
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(a)

# %%
plt.plot(a[50])
# Out:
# [<matplotlib.lines.Line2D at 0x1cf42d02860>,
#  <matplotlib.lines.Line2D at 0x1cf42d029b0>,
#  <matplotlib.lines.Line2D at 0x1cf42d02b00>]

# %%
a = cv2.imread("Sign.jpg")
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
red = 0
blue = 0
count = 0 
for i in range(len(a)):
    for j in range(len(a[0])):
        count += 1
        if not (a[i][j][2] > a[i][j][0] and a[i][j][0]<150):
            a[i][j][0] = 255
            a[i][j][1] = 255
            a[i][j][2] = 255
#         else:
#             a[i][j][0] = 0
#             a[i][j][1] = 0
#             a[i][j][2] = 0

# %%
plt.imshow(a)

# %%
a = cv2.cvtColor(a, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('new_sign.jpg', a)
# Out:
# True
