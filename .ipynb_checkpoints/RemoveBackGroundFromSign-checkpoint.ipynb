# %%
import cv2
import matplotlib.pyplot as plt

# %%
old_img = cv2.imread("Sign.jpg")
old_img = cv2.cvtColor(old_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(old_img)

# %%
plt.plot(old_img[50])

# %%
old_img = cv2.imread("Sign.jpg")
old_img = cv2.cvtColor(old_img, cv2.COLOR_BGR2RGB)
red = 0
blue = 0
count = 0 
for i in range(len(old_img)):
    for j in range(len(old_img[0])):
        count += 1
        if not (old_img[i][j][2] > old_img[i][j][0] and old_img[i][j][0]<150):
            old_img[i][j][0] = 255
            old_img[i][j][1] = 255
            old_img[i][j][2] = 255
#         else:
#             a[i][j][0] = 0
#             a[i][j][1] = 0
#             a[i][j][2] = 0

# %%
plt.imshow(old_img)

# %%
new_img = cv2.cvtColor(old_img, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('new_sign.jpg', new_img)
# Out:
# True
